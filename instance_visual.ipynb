# %%
import pandas as pd

# Replace 'your_file.csv' with the path to your CSV file
df = pd.read_csv('Daily_Demand_Forecasting_Orders.csv', sep = ";")
df
# Out:
#     Week of the month (first week, second, third, fourth or fifth week)  \
# 0                                                   1
# 1                                                   1
# 2                                                   1
# 3                                                   2
# 4                                                   2
# 5                                                   2
# 6                                                   2
# 7                                                   2
# 8                                                   3
# 9                                                   3
# 10                                                  3
# 11                                                  3
# 12                                                  3
# 13                                                  4
# 14                                                  4
# 15                                                  4
# ...

# %%
df.plot(y='Target (Total orders)', kind='line', title='Total Orders Over Time')
# Out:
# <AxesSubplot:title={'center':'Total Orders Over Time'}>
